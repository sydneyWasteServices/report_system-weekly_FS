# %%
import pandas as pd
# path = "~/c/Users/gordon/Desktop/"

df1 = pd.read_csv("../../../dataVault/waste_edge_booking_data/1.csv")
df1['Customer number']
# Out:
# 0         4135.000
# 1         3340.000
# 2         4065.000
# 3         3932.000
# 4         3932.000
#             ...
# 242775    2459.012
# 242776    3973.000
# 242777    3552.000
# 242778    3886.000
# 242779    3028.000
# Name: Customer number, Length: 242780, dtype: float64

# %%
df2 = pd.read_csv("../../../dataVault/waste_edge_booking_data/2.csv")
df2
# Out:
#            Job No      Date Schd Time Start Schd Time End    Latitude  \
# 0       2618756.0  22/01/21           12:19         06:35  151.168271
# 1       2618762.0  22/01/21           12:18         06:38  151.138844
# 2       2618754.0  22/01/21           12:15         06:35  151.138540
# 3       2601301.0  22/01/21           00:00         00:00  115.762050
# 4       2607936.0  22/01/21           00:00         06:08  151.205418
# ...           ...       ...             ...           ...         ...
# 257837  2407043.0  22/07/20             NaN         10:16  151.222345
# 257838  2407044.0  22/07/20             NaN         13:18  151.213561
# 257839  2407045.0  22/07/20             NaN         13:18  151.211405
# 257840  2407046.0  22/07/20             NaN         10:15  151.242349
# 257841  2407047.0  22/07/20             NaN         13:18  151.197714
#
#         Longitude  Customer number                           Customer Name  \
# ...
